# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import g_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  al qusayr  34.5091   36.5798     18.10        82           0
# 1        1   waitangi -43.9535 -176.5597     19.16        96         100
# 2        2   uliastay  47.7417   96.8444      6.08        54         100
# 3        3    colonia  50.9333    6.9500     18.51        79          75
# 4        4  essaouira  31.5125   -9.7700     21.88        79           8
#
#    Wind Speed Country        Date
# 0        0.43      SY  2024-4-102
# 1        3.58      NZ  2024-4-102
# 2        2.87      MN  2024-4-102
# 3        1.54      DE  2024-4-102
# 4        6.30      MA  2024-4-102

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha=0.5)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
cond1 = city_data_df['Max Temp'] <= 23
cond2 = city_data_df['Humidity'] <= 60
cond3 = city_data_df['Cloudiness'] >= 20.0
ideal_cities_df = city_data_df.where(cond1 & cond2 & cond3)

# Drop any rows with null values
# YOUR CODE HERE
ideal_cities_df = ideal_cities_df.dropna()

# Display sample data
# YOUR CODE HERE
ideal_cities_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 2        2.0        uliastay  47.7417   96.8444      6.08      54.0
# 31      31.0           lhasa  29.6500   91.1000      7.72      57.0
# 34      34.0           choyr  46.3611  108.3611     10.46      46.0
# 56      56.0         college  64.8569 -147.8028      6.58      59.0
# 70      70.0         kalecik  40.0972   33.4083     19.10      53.0
# 73      73.0            kulu  39.0951   33.0799     17.93      59.0
# 94      94.0  grande prairie  55.1667 -118.8027     13.25      32.0
# 133    133.0         birjand  32.8663   59.2211     19.41      59.0
# 144    144.0          robbah  33.2797    6.9098     19.58      48.0
# 149    149.0        la sarre  48.8002  -79.1996     15.82      58.0
# 185    185.0   prince george  53.9166 -122.7530     14.42      52.0
# 190    190.0           nagqu  31.5000   92.0000      1.49      49.0
# 198    198.0         shahrak  34.1074   64.3052     15.69      47.0
# 264    264.0     sol'-iletsk  51.1631   54.9918     13.98      59.0
# 316    316.0          viedma -40.8135  -62.9967     20.64      30.0
# 326    326.0    tres arroyos -38.3739  -60.2798     19.43      41.0
# 337    337.0        portland  45.5234 -122.6762     19.95      59.0
# 353    353.0   puerto madryn -42.7692  -65.0385     19.56      38.0
# 354    354.0          vernon  50.2581 -119.2691     17.38      44.0
# 361    361.0     east london -33.0153   27.9116     20.76      58.0
# 400    400.0           sucre -19.0333  -65.2627     22.23      56.0
# 402    402.0      slave lake  55.2834 -114.7690     14.80      31.0
# 409    409.0            nili  33.7218   66.1302     16.37      37.0
# 421    421.0          gaiman -43.2897  -65.4929     21.02      19.0
# 422    422.0         jiangzi  28.9500   89.6333     -0.70      49.0
# 426    426.0     peace river  56.2501 -117.2860     15.32      32.0
# 429    429.0          bamyan  34.7500   67.2500      7.24      55.0
# 462    462.0       saynshand  44.8824  110.1163     15.58      26.0
# 481    481.0          pierre  44.3683 -100.3510     17.51      33.0
# 521    521.0    villa gesell -37.2639  -56.9730     17.62      58.0
# 353   puerto madryn      AR -42.7692  -65.0385      38.0
# 354          vernon      CA  50.2581 -119.2691      44.0
# 361     east london      ZA -33.0153   27.9116      58.0
# 400           sucre      BO -19.0333  -65.2627      56.0
# 402      slave lake      CA  55.2834 -114.7690      31.0
# 409            nili      AF  33.7218   66.1302      37.0
# 421          gaiman      AR -43.2897  -65.4929      19.0
# 422         jiangzi      CN  28.9500   89.6333      49.0
# 426     peace river      CA  56.2501 -117.2860      32.0
# 429          bamyan      AF  34.7500   67.2500      55.0
# 462       saynshand      MN  44.8824  110.1163      26.0
# 481          pierre      US  44.3683 -100.3510      33.0
# 521    villa gesell      AR -37.2639  -56.9730      58.0
# 522       dzhangala      KZ  49.2167   50.3333      48.0
# 527          dryden      CA  49.7833  -92.7503      57.0
# 534        st. paul      US  44.9444  -93.0933      45.0
# 572          nurota      UZ  40.5614   65.6886      53.0

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    # YOUR CODE HERE
    "apiKey": g_key,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    params["categories"] = "accommodation.hotel"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()
    # print(name_address)

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    

# Display sample data
hotel_df
# Out:
# Starting hotel search
# uliastay - nearest hotel: Болоржин зочид буудал
# lhasa - nearest hotel: Shangri-la Hotel Lhasa
# choyr - nearest hotel: Сансар Хайрхан зочид буудал
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# kalecik - nearest hotel: No hotel found
# kulu - nearest hotel: No hotel found
# grande prairie - nearest hotel: Sandman Hotel Grande Prairie
# birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# robbah - nearest hotel: No hotel found
# la sarre - nearest hotel: Motel le Bivouac
# prince george - nearest hotel: Travelodge by Wyndham Prince George
# nagqu - nearest hotel: Naqu Hotel
# shahrak - nearest hotel: No hotel found
# sol'-iletsk - nearest hotel: Konnov hotel
# viedma - nearest hotel: Níjar
# tres arroyos - nearest hotel: Andrea Hotel
# portland - nearest hotel: the Hoxton
# puerto madryn - nearest hotel: Hotel Gran Palace
# vernon - nearest hotel: Okanagan Royal Park Inn
# east london - nearest hotel: No hotel found
# sucre - nearest hotel: El Gobernador Hostal
# slave lake - nearest hotel: Northwest Inn
# nili - nearest hotel: No hotel found
# gaiman - nearest hotel: yr hen ffordd
# jiangzi - nearest hotel: Yeti Hotel
# peace river - nearest hotel: New Ridge Inn
# bamyan - nearest hotel: No hotel found
# saynshand - nearest hotel: No hotel found
# pierre - nearest hotel: Quality Inn
# villa gesell - nearest hotel: Hotel El Faro
# dzhangala - nearest hotel: Жаңақала ЛПУ жатақханасы
# dryden - nearest hotel: Holiday Inn Express
# st. paul - nearest hotel: Crowne Plaza
# nurota - nearest hotel: Nurota
#                City Country      Lat       Lng  Humidity  \
# 2          uliastay      MN  47.7417   96.8444      54.0
# 31            lhasa      CN  29.6500   91.1000      57.0
# 34            choyr      MN  46.3611  108.3611      46.0
# 56          college      US  64.8569 -147.8028      59.0
# 70          kalecik      TR  40.0972   33.4083      53.0
# 73             kulu      TR  39.0951   33.0799      59.0
# 94   grande prairie      CA  55.1667 -118.8027      32.0
# 133         birjand      IR  32.8663   59.2211      59.0
# 144          robbah      DZ  33.2797    6.9098      48.0
# 149        la sarre      CA  48.8002  -79.1996      58.0
# 185   prince george      CA  53.9166 -122.7530      52.0
# 190           nagqu      CN  31.5000   92.0000      49.0
# 198         shahrak      AF  34.1074   64.3052      47.0
# 264     sol'-iletsk      RU  51.1631   54.9918      59.0
# 316          viedma      AR -40.8135  -62.9967      30.0
# 326    tres arroyos      AR -38.3739  -60.2798      41.0
# 337        portland      US  45.5234 -122.6762      59.0
# 353   puerto madryn      AR -42.7692  -65.0385      38.0
# 354          vernon      CA  50.2581 -119.2691      44.0
# 361     east london      ZA -33.0153   27.9116      58.0
# 400           sucre      BO -19.0333  -65.2627      56.0
# 402      slave lake      CA  55.2834 -114.7690      31.0
# 409            nili      AF  33.7218   66.1302      37.0
# 421          gaiman      AR -43.2897  -65.4929      19.0
# 422         jiangzi      CN  28.9500   89.6333      49.0
# 426     peace river      CA  56.2501 -117.2860      32.0
# 429          bamyan      AF  34.7500   67.2500      55.0
# 462       saynshand      MN  44.8824  110.1163      26.0
# 481          pierre      US  44.3683 -100.3510      33.0
# 521    villa gesell      AR -37.2639  -56.9730      58.0
# 522       dzhangala      KZ  49.2167   50.3333      48.0
# 527          dryden      CA  49.7833  -92.7503      57.0
# 534        st. paul      US  44.9444  -93.0933      45.0
# 572          nurota      UZ  40.5614   65.6886      53.0
#
#                               Hotel Name
# 2                  Болоржин зочид буудал
# 31                Shangri-la Hotel Lhasa
# 34           Сансар Хайрхан зочид буудал
# 56    BEST WESTERN PLUS Pioneer Park Inn
# 70                        No hotel found
# 73                        No hotel found
# 94          Sandman Hotel Grande Prairie
# 133            مهمانسرای جهانگردی بیرجند
# 144                       No hotel found
# 149                     Motel le Bivouac
# 185  Travelodge by Wyndham Prince George
# 190                           Naqu Hotel
# 198                       No hotel found
# 264                         Konnov hotel
# 316                                Níjar
# 326                         Andrea Hotel
# 337                           the Hoxton
# 353                    Hotel Gran Palace
# 354              Okanagan Royal Park Inn
# 361                       No hotel found
# 400                 El Gobernador Hostal
# 402                        Northwest Inn
# 409                       No hotel found
# 421                        yr hen ffordd
# 422                           Yeti Hotel
# 426                        New Ridge Inn
# 429                       No hotel found
# 462                       No hotel found
# 481                          Quality Inn
# 521                        Hotel El Faro
# 522             Жаңақала ЛПУ жатақханасы
# 527                  Holiday Inn Express
# 534                         Crowne Plaza
# 572                               Nurota

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
mapb = hotel_df.hvplot.points('Lng', 'Lat', 
    geo=True, tiles = True, alpha=0.70, marker='o', 
    frame_width = 700, frame_height = 500,
    s='Humidity', c='City', 
    hover_alpha=1, 
    hover_cols=['Hotel Name', 'Country']
)
# Display the map
# YOUR CODE HERE
mapb
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
